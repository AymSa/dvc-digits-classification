# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27018")
db = client.get_database("prediction_service")

# %%
collection = db.get_collection("data")
data = list(collection.find())

# %%
data
# Out:
# [{'_id': ObjectId('6418aeed41f21bf12786ceef'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1},
#  {'_id': ObjectId('6418bb43326ddf09ff7dd74c'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': 1},
#  {'_id': ObjectId('6418bb8e326ddf09ff7dd74d'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1},
#  {'_id': ObjectId('6418bb95326ddf09ff7dd74e'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1},
#  {'_id': ObjectId('6418bb9a326ddf09ff7dd74f'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1},
#  {'_id': ObjectId('6418bba1326ddf09ff7dd750'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': 1},
#  {'_id': ObjectId('6418bc76326ddf09ff7dd751'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1},
#  {'_id': ObjectId('6418cab779b343bd3b32296c'),
#   'imgb64': b'data:image/png;base64,...',
#   'prediction': -1}]

# %%
len(data)
# Out:
# 8
